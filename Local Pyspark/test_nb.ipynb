# %%
# import sys
# from pathlib import Path

# Add the Databricks directory to the Python path
# sys.path.insert(0, str(Path.cwd() / 'Code' / 'Databricks'))

# Import the class from class.py

import importlib
import GetStockData_class  # Import the module, not just the class

# Reload the module to reflect any changes
importlib.reload(GetStockData_class)

from GetStockData_class import GetStockData  # Replace MyClass with the actual class name in class.py

# %%
import json

stock_data = GetStockData("23c1a7c2da0148c584eac977ac756432")
data = stock_data.get_historical_stock_data()

print(json.dumps(data,indent=4))
# Out:
# data saved for symbol QQQ and date range 2021-01-01 to 2021-12-31.
# data saved for symbol VOO and date range 2021-01-01 to 2021-12-31.
# [
#     {
#         "meta": {
#             "symbol": "QQQ",
#             "interval": "1day",
#             "currency": "USD",
#             "exchange_timezone": "America/New_York",
#             "exchange": "NASDAQ",
#             "mic_code": "XNMS",
#             "type": "ETF"
#         },
#         "values": [
#             {
#                 "datetime": "2021-12-30",
#                 "open": "401.32999",
#                 "high": "403.57001",
#                 "low": "399.75000",
#                 "close": "400.35001",
#                 "volume": "23850100"
#             },
#             {
#                 "datetime": "2021-12-29",
#                 "open": "401.75000",
#                 "high": "403.04999",
#                 "low": "399.10999",
#                 "close": "401.54999",
#                 "volume": "32248500"
#             },
# ...

# %%
from pyspark.sql import SparkSession 

spark = SparkSession.builder.getOrCreate()

# Set log level to ERROR to suppress warnings
spark.sparkContext.setLogLevel("ERROR")

df = spark.createDataFrame(
    [("Andrew", 26),
    ("Vlad", 25)], 
    ["Name", "Age"] 
)


df.show(truncate=False)
# Out:
# +------+---+
# |Name  |Age|
# +------+---+
# |Andrew|26 |
# |Vlad  |25 |
# +------+---+
